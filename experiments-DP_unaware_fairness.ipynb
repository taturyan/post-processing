# %%
from evaluation import evaluate_DP_unaware
from plots import plot_compare

# %% [markdown]
# # Experiments on Communities & Crime dataset

# %%
DATASET = 'communities'
NUM = 10
EPS_LIST = []
#i_list  = [1.4, 2, 4, 5, 6, 8, 16, 32, 128, 512]
i_list  = [1.3, 2, 4, 8, 16, 32, 512]
for i in i_list:
    EPS_LIST+=[[2**(-i), 2**(-i)]]
K = 2
T = 15000
results_PostProc_communities = evaluate_DP_unaware(dataset=DATASET, num=NUM, K=K, T=T, eps_list=EPS_LIST, 
                            print_details = True, beta='auto', 
                            alg={'base':'SGD3', 'method':'ACSA2'},
                            TRAIN_SIZE=0.4, UNLAB_SIZE=0.4, TEST_SIZE=0.2, data_scaling=False)
results_PostProc_communities
# Out:
# 1 / 7  : collecting statistics for eps=[0.40612619817811774, 0.40612619817811774]
# -----    1 / 10 : training completed, statistics collected
# -----    2 / 10 : training completed, statistics collected
# -----    3 / 10 : training completed, statistics collected
# -----    4 / 10 : training completed, statistics collected
# -----    5 / 10 : training completed, statistics collected
# -----    6 / 10 : training completed, statistics collected
# -----    7 / 10 : training completed, statistics collected
# -----    8 / 10 : training completed, statistics collected
# -----    9 / 10 : training completed, statistics collected
# -----    10 / 10 : training completed, statistics collected
# ---------------------------------------------------------
# 2 / 7  : collecting statistics for eps=[0.25, 0.25]
# -----    1 / 10 : training completed, statistics collected
# -----    2 / 10 : training completed, statistics collected
# -----    3 / 10 : training completed, statistics collected
# ...

# %%
results_fairlearn_communities_1 = {'risk': {'mean': [0.17689693244599214,
   0.22009789171100316,
   0.2786845485095133,
   0.30046466556830975,
   0.30221636020245235],
  'std': [0.01831495706189558,
   0.02289279215933043,
   0.025551122581054245,
   0.02295246505068253,
   0.0230453393075976]},
 'unf': {0: {'mean': [0.3886419964583844,
    0.2680233497120416,
    0.08871475487840459,
    0.04005772991476082,
    0.03642251688802759],
   'std': [0.052671090894521724,
    0.0498945313744904,
    0.032411360272069804,
    0.022502600400054747,
    0.02240860858145162]},
  1: {'mean': [0.10430008850640346,
    0.07192958906010083,
    0.023808432619124586,
    0.01075031729341831,
    0.009774732966754985],
   'std': [0.014135372636229588,
    0.01339022567238709,
    0.008698256430843017,
    0.006039036529088186,
    0.006013811887673927]}},
 'training_time_hist': [4.398838043212891,
  3.934633255004883,
  3.098637580871582,
  6.522243976593018,
  6.178001165390015,
  8.433231353759766,
  7.377379655838013,
  6.300330877304077,
  6.193673372268677,
  7.102952003479004,
  8.005863666534424,
  9.227206468582153,
  7.823686122894287,
  6.390861511230469,
  5.9138383865356445,
  7.149146556854248,
  7.826409101486206,
  5.606290817260742,
  2.751678466796875,
  3.9744651317596436,
  7.8080832958221436,
  7.590933084487915,
  7.170180320739746,
  6.70776104927063,
  7.044357538223267,
  6.858175992965698,
  6.6340553760528564,
  7.081171989440918,
  6.53021502494812,
  7.09217381477356,
  7.082601308822632,
  7.907301902770996,
  7.645926237106323,
  6.699535846710205,
  7.011561870574951,
  6.371380805969238,
  6.755277872085571,
  8.44034457206726,
  4.749148368835449,
  3.9556500911712646,
  3.9839255809783936,
  8.133901357650757,
  7.104490756988525,
  6.904387474060059,
  6.41167426109314,
  6.844352960586548,
  5.944097280502319,
  7.669551372528076,
  7.2296302318573,
  4.071073532104492]}

# %%
results_fairlearn_communities_2 = {'risk': {'mean': [0.18399662722813,
   0.2231034563576601,
   0.28037323107666556,
   0.30015010529689307,
   0.3007082563912167],
  'std': [0.026096515158909515,
   0.025646902359284084,
   0.029773965558912523,
   0.03155323033785705,
   0.03455494360404223]},
 'unf': {0: {'mean': [0.390849950564362,
    0.2729827671726905,
    0.10609509578010727,
    0.06091481606091699,
    0.06471548730641549],
   'std': [0.06866437449989013,
    0.06639489110908037,
    0.048673094762436794,
    0.03630192716105079,
    0.036833825952318905]},
  1: {'mean': [0.10489263849011624,
    0.073260550934524,
    0.028472805257281207,
    0.016347746163313248,
    0.017367734612584163],
   'std': [0.018427499865785273,
    0.017818437230552094,
    0.0130624279873632,
    0.009742370228524897,
    0.009885116230015327]}},
 'training_time_hist': [1.900620937347412,
  2.564542293548584,
  2.088358163833618,
  2.265904664993286,
  2.354522466659546,
  1.9646015167236328,
  2.632678985595703,
  3.903684616088867,
  3.901247262954712,
  3.9556093215942383,
  3.51322603225708,
  3.3430979251861572,
  3.565101385116577,
  3.4069128036499023,
  4.227920293807983,
  3.46767258644104,
  4.099030494689941,
  3.3286936283111572,
  3.919351816177368,
  4.218032121658325,
  3.3704464435577393,
  4.042669296264648,
  3.874870777130127,
  2.1317760944366455,
  2.871690273284912,
  2.2398431301116943,
  1.8980302810668945,
  1.918116569519043,
  1.841825246810913,
  2.2261598110198975,
  1.6313881874084473,
  1.8116817474365234,
  1.7531254291534424,
  1.9924969673156738,
  2.045189142227173,
  1.997267484664917,
  1.8654184341430664,
  1.7617802619934082,
  1.7509520053863525,
  2.020083427429199,
  1.6438958644866943,
  1.8251628875732422,
  1.6977126598358154,
  1.9223365783691406,
  1.7239034175872803,
  2.0611701011657715,
  1.8297793865203857,
  1.801361322402954,
  1.7939810752868652,
  1.9848968982696533]}

# %%
pairs_list = [[results_PostProc_communities['unfairness'][0], results_PostProc_communities['risk']],
              [results_fairlearn_communities_1['unf'][0],results_fairlearn_communities_1['risk']],
              [results_fairlearn_communities_2['unf'][0],results_fairlearn_communities_2['risk']],
              [results_PostProc_communities['base_unfairness'][0], results_PostProc_communities['base_risk_argmax']]]
model_list = [r'$COPT (T=4000)$',r'$fairlearn-1$',r'$fairlearn-2$',r'$base$']
markers_list = ['o', 's','^','x']
dataset='communities&crime'
colors=['tab:green','tab:orange','tab:blue','tab:red']

plot_compare(pairs_list=pairs_list, model_list=model_list,
                        markers_list=markers_list, dataset=dataset, 
                        x_label = 'unfairness', y_label = 'risk',
                        colors = colors, legend_size=8, alpha=0.7, 
                        plot_std=True, annotate=False, loglog=False, start_0=False, linestyle='dashed')

# %%
DATASET = 'communities'
NUM = 10
EPS_LIST = []
#i_list  = [1.4, 2, 4, 5, 6, 8, 16, 32, 128, 512]
i_list  = [1.4, 2, 4, 8, 16, 32, 512]
for i in i_list:
    EPS_LIST+=[[2**(-i), 2**(-i)]]
K = 2
T = 5000
results_PostProc_communities_ = evaluate_DP_unaware(dataset=DATASET, num=NUM, K=K, T=T, eps_list=EPS_LIST, 
                            print_details = True, beta='auto', 
                            alg={'base':'SGD3', 'method':'ACSA2'},
                            TRAIN_SIZE=0.4, UNLAB_SIZE=0.4, TEST_SIZE=0.2, data_scaling=False)
results_PostProc_communities_
# Out:
# 1 / 7  : collecting statistics for eps=[0.37892914162759955, 0.37892914162759955]
# -----    1 / 10 : training completed, statistics collected
# -----    2 / 10 : training completed, statistics collected
# -----    3 / 10 : training completed, statistics collected
# -----    4 / 10 : training completed, statistics collected
# -----    5 / 10 : training completed, statistics collected
# -----    6 / 10 : training completed, statistics collected
# -----    7 / 10 : training completed, statistics collected
# -----    8 / 10 : training completed, statistics collected
# -----    9 / 10 : training completed, statistics collected
# -----    10 / 10 : training completed, statistics collected
# ---------------------------------------------------------
# 2 / 7  : collecting statistics for eps=[0.25, 0.25]
# -----    1 / 10 : training completed, statistics collected
# -----    2 / 10 : training completed, statistics collected
# -----    3 / 10 : training completed, statistics collected
# ...

# %%
pairs_list = [[results_PostProc_communities_['unfairness'][0], results_PostProc_communities_['risk']],
              [results_fairlearn_communities_1['unf'][0],results_fairlearn_communities_1['risk']],
              [results_fairlearn_communities_2['unf'][0],results_fairlearn_communities_2['risk']],
              [results_PostProc_communities_['base_unfairness'][0], results_PostProc_communities_['base_risk_argmax']]]
model_list = [r'$COPT (T=5000)$',r'$fairlearn-1$',r'$fairlearn-2$',r'$base$']
markers_list = ['o', 's','^','x']
dataset='communities&crime'
colors=['tab:green','tab:orange','tab:blue','tab:red']

plot_compare(pairs_list=pairs_list, model_list=model_list,
                        markers_list=markers_list, dataset=dataset, 
                        x_label = 'unfairness', y_label = 'risk',
                        colors = colors, legend_size=8, alpha=0.7, 
                        plot_std=True, annotate=False, loglog=False, start_0=False, linestyle='dashed')

# %% [markdown]
# # Experiments on Adult dataset

# %%
DATASET = 'adult'
NUM = 10
EPS_LIST = []
i_list  = [1, 2, 4, 5, 6, 8, 16, 32, 128]
for i in i_list:
    EPS_LIST+=[[2**(-i), 2**(-i)]]
K = 2
T = 8000
results_PostProc_adult = evaluate_DP_unaware(dataset=DATASET, num=NUM, K=K, T=T, eps_list=EPS_LIST, 
                            print_details = True, beta='auto', 
                            alg={'base':'SGD3', 'method':'ACSA2'},
                            TRAIN_SIZE=0.4, UNLAB_SIZE=0.4, TEST_SIZE=0.2, data_scaling=True)
results_PostProc_adult
# Out:
# 1 / 9  : collecting statistics for eps=[0.5, 0.5]
# -----    1 / 10 : training completed, statistics collected
# -----    2 / 10 : training completed, statistics collected
# -----    3 / 10 : training completed, statistics collected
# -----    4 / 10 : training completed, statistics collected
# -----    5 / 10 : training completed, statistics collected
# -----    6 / 10 : training completed, statistics collected
# -----    7 / 10 : training completed, statistics collected
# -----    8 / 10 : training completed, statistics collected
# -----    9 / 10 : training completed, statistics collected
# -----    10 / 10 : training completed, statistics collected
# ---------------------------------------------------------
# 2 / 9  : collecting statistics for eps=[0.25, 0.25]
# -----    1 / 10 : training completed, statistics collected
# -----    2 / 10 : training completed, statistics collected
# -----    3 / 10 : training completed, statistics collected
# ...

# %%
results_fairlearn_adult_1 = {'risk': {'mean': [0.18624999999999997,
   0.18624999999999997,
   0.1909067311684218,
   0.21991071306513477,
   0.22191877005356],
  'std': [0.020440462323538574,
   0.020440462323538574,
   0.023194931968103107,
   0.022428249809559198,
   0.022351360968982003]},
 'unf': {0: {'mean': [0.08449999999999999,
    0.08449999999999999,
    0.061163181039174806,
    0.015635144096207865,
    0.014171749662312017],
   'std': [0.019496661829277524,
    0.019496661829277524,
    0.02577716966206068,
    0.01819476872639065,
    0.02032219063160888]},
  1: {'mean': [0.04068518518518517,
    0.04068518518518517,
    0.029448939018862107,
    0.007528032342618595,
    0.006823435022594781],
   'std': [0.009387281621504004,
    0.009387281621504004,
    0.012411229837288264,
    0.008760444201595491,
    0.009784758452256194]}},
 'training_time_hist': [0.3130476474761963,
  0.3417942523956299,
  0.24944400787353516,
  0.251176118850708,
  0.34978175163269043,
  0.3674657344818115,
  0.28377723693847656,
  0.2692744731903076,
  0.3344714641571045,
  0.29362940788269043,
  0.3412015438079834,
  0.3360021114349365,
  0.2564210891723633,
  0.2451457977294922,
  0.341641902923584,
  0.3363044261932373,
  0.24095702171325684,
  0.25997304916381836,
  0.345043420791626,
  0.3053288459777832,
  0.26095080375671387,
  0.2718174457550049,
  0.22353744506835938,
  0.26874637603759766,
  0.21014404296875,
  0.24978017807006836,
  0.25036191940307617,
  0.22650861740112305,
  0.28241562843322754,
  0.3001115322113037,
  0.2591738700866699,
  0.30186963081359863,
  0.2253866195678711,
  0.26662468910217285,
  0.26563191413879395,
  0.2455589771270752,
  0.2882678508758545,
  0.3046565055847168,
  0.2404179573059082,
  0.28804755210876465,
  0.26442575454711914,
  0.2672700881958008,
  0.23462152481079102,
  0.31128764152526855,
  0.2888221740722656,
  0.2797880172729492,
  0.3071248531341553,
  0.2629544734954834,
  0.2668461799621582,
  0.2797110080718994]}

# %%
results_fairlearn_adult_2 = {'risk': {'mean': [0.19,
   0.19,
   0.1961852747450091,
   0.22489476561281166,
   0.22693247140419076],
  'std': [0.01650757401921918,
   0.01650757401921918,
   0.019314691058362653,
   0.018096295008026814,
   0.01808901932684631]},
 'unf': {0: {'mean': [0.09548076923076926,
    0.09548076923076926,
    0.05641913030710449,
    0.020311846070781358,
    0.020967514632887974],
   'std': [0.016226086181857453,
    0.016226086181857453,
    0.025387669254263782,
    0.014705929688666018,
    0.014685605561857478]},
  1: {'mean': [0.04597222222222223,
    0.04597222222222223,
    0.02716476644416138,
    0.009779777737783824,
    0.010095470008427776],
   'std': [0.007812560013486887,
    0.007812560013486887,
    0.012223692603904468,
    0.0070806328130618166,
    0.007070847122376078]}},
 'training_time_hist': [0.2354273796081543,
  0.25498056411743164,
  0.28641581535339355,
  0.20010995864868164,
  0.2916874885559082,
  0.3439488410949707,
  0.31214141845703125,
  0.26001524925231934,
  0.32007503509521484,
  0.3296489715576172,
  0.3448457717895508,
  0.3200650215148926,
  0.31722331047058105,
  0.23513460159301758,
  0.2929356098175049,
  0.2544591426849365,
  0.30750179290771484,
  0.26857423782348633,
  0.26662492752075195,
  0.23981451988220215,
  0.2856326103210449,
  0.2657928466796875,
  0.25985288619995117,
  0.43575143814086914,
  0.2643160820007324,
  0.27041101455688477,
  0.3100731372833252,
  0.22483181953430176,
  0.28461337089538574,
  0.23016667366027832,
  0.24178600311279297,
  0.22646164894104004,
  0.26891326904296875,
  0.23509693145751953,
  0.2542288303375244,
  0.2375321388244629,
  0.2325153350830078,
  0.22485566139221191,
  0.24676752090454102,
  0.22015857696533203,
  0.20424413681030273,
  0.1886734962463379,
  0.24243879318237305,
  0.2191319465637207,
  0.24124455451965332,
  0.22896838188171387,
  0.2843351364135742,
  0.216461181640625,
  0.24132585525512695,
  0.21659111976623535]}

# %%
pairs_list = [[results_PostProc_adult['unfairness'][0], results_PostProc_adult['risk']],
              [results_fairlearn_adult_1['unf'][0],results_fairlearn_adult_1['risk']],
              [results_fairlearn_adult_2['unf'][0],results_fairlearn_adult_2['risk']],
              [results_PostProc_adult['base_unfairness'][0], results_PostProc_adult['base_risk_argmax']]]
model_list = [r'$COPT$',r'$fairlearn-1$',r'$fairlearn-2$',r'$base$']
markers_list = ['o', 's','^','x']
dataset=r'$adult$'
colors=['tab:green','tab:orange','tab:blue', 'tab:red']

plot_compare(pairs_list=pairs_list, model_list=model_list,
                        markers_list=markers_list, dataset=dataset, 
                        x_label = r'$unfairness$', y_label = r'$risk$',
                        colors = colors, legend_size=8, alpha=0.7, 
                        plot_std=True, annotate=False, loglog=False, start_0=False, linestyle='dashed')
